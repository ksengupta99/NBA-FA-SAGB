# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import Perceptron
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.utils import shuffle

from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
adv_stats2017 = pd.read_csv('player-data/player2017/Adv-2017.csv')
adv_stats2017 = adv_stats2017.drop(['Unnamed: 19','Unnamed: 24'], axis = 1)
adv_stats2017.rename(columns = {'Tm': 'team'}, inplace = True)
adv_stats2017.head()
# Out:
#    Rk                  Player Pos  Age team   G    MP   PER    TS%   3PAr  \
# 0   1  Alex Abrines\abrinal01  SG   23  OKC  68  1055  10.1  0.560  0.724
# 1   2      Quincy Acy\acyqu01  PF   26  TOT  38   558  11.8  0.565  0.529
# 2   2      Quincy Acy\acyqu01  PF   26  DAL   6    48  -1.4  0.355  0.412
# 3   2      Quincy Acy\acyqu01  PF   26  BRK  32   510  13.1  0.587  0.542
# 4   3  Steven Adams\adamsst01   C   23  OKC  80  2389  16.5  0.589  0.002
#
#    ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP
# 0  ...    8.3  15.9  1.2  0.9  2.1  0.096  -0.3  -2.2  -2.5  -0.1
# 1  ...    9.7  16.8  0.5  0.5  0.9  0.082  -1.8  -1.2  -3.0  -0.1
# 2  ...    9.8  20.0 -0.2  0.0 -0.1 -0.133 -10.1  -6.0 -16.2  -0.2
# 3  ...    9.6  16.5  0.6  0.5  1.1  0.102  -1.1  -0.7  -1.8   0.0
# 4  ...   16.0  16.2  3.3  3.1  6.5  0.130  -0.7   1.2   0.6   1.5
#
# [5 rows x 27 columns]

# %%
name_temp = adv_stats2017['Player'].map(lambda x: 
                                        re.sub("[^a-zA-Z]+", "", 
                                               re.search("^.*(?=\\\\)", x).group(0).replace(" ", "").lower()))
adv_stats2017.insert(1, 'name', name_temp.map(lambda x: re.sub("[^a-zA-Z]+", "", x)))
adv_stats2017.head()
# Out:
#    Rk         name                  Player Pos  Age team   G    MP   PER  \
# 0   1  alexabrines  Alex Abrines\abrinal01  SG   23  OKC  68  1055  10.1
# 1   2    quincyacy      Quincy Acy\acyqu01  PF   26  TOT  38   558  11.8
# 2   2    quincyacy      Quincy Acy\acyqu01  PF   26  DAL   6    48  -1.4
# 3   2    quincyacy      Quincy Acy\acyqu01  PF   26  BRK  32   510  13.1
# 4   3  stevenadams  Steven Adams\adamsst01   C   23  OKC  80  2389  16.5
#
#      TS%  ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP
# 0  0.560  ...    8.3  15.9  1.2  0.9  2.1  0.096  -0.3  -2.2  -2.5  -0.1
# 1  0.565  ...    9.7  16.8  0.5  0.5  0.9  0.082  -1.8  -1.2  -3.0  -0.1
# 2  0.355  ...    9.8  20.0 -0.2  0.0 -0.1 -0.133 -10.1  -6.0 -16.2  -0.2
# 3  0.587  ...    9.6  16.5  0.6  0.5  1.1  0.102  -1.1  -0.7  -1.8   0.0
# 4  0.589  ...   16.0  16.2  3.3  3.1  6.5  0.130  -0.7   1.2   0.6   1.5
#
# [5 rows x 28 columns]

# %%
#Takes in a dataframe, a position column name ("Pos" for stats df, "position" for salary df), 
#and index to insert new column into (4 for stats df, 5 for salary df).
#So call to a stats df should be posBigOrSmall(stats_df, "Pos", 4) 
#and for salary df posBigOrSmall(salary_df, "position", 5)
def posBigOrSmall(df, pos_colname, col_index):
    pos = []
    for i in range(len(df)):
        if df[pos_colname][i] == "PG" or df[pos_colname][i] == "SG":
            pos.append("small")
        else:
            pos.append("big")
    df.insert(col_index, 'pos', pos)

# %%
posBigOrSmall(adv_stats2017, "Pos", 4) 
adv_stats2017.head()
# Out:
#    Rk         name                  Player Pos    pos  Age team   G    MP  \
# 0   1  alexabrines  Alex Abrines\abrinal01  SG  small   23  OKC  68  1055
# 1   2    quincyacy      Quincy Acy\acyqu01  PF    big   26  TOT  38   558
# 2   2    quincyacy      Quincy Acy\acyqu01  PF    big   26  DAL   6    48
# 3   2    quincyacy      Quincy Acy\acyqu01  PF    big   26  BRK  32   510
# 4   3  stevenadams  Steven Adams\adamsst01   C    big   23  OKC  80  2389
#
#     PER  ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP
# 0  10.1  ...    8.3  15.9  1.2  0.9  2.1  0.096  -0.3  -2.2  -2.5  -0.1
# 1  11.8  ...    9.7  16.8  0.5  0.5  0.9  0.082  -1.8  -1.2  -3.0  -0.1
# 2  -1.4  ...    9.8  20.0 -0.2  0.0 -0.1 -0.133 -10.1  -6.0 -16.2  -0.2
# 3  13.1  ...    9.6  16.5  0.6  0.5  1.1  0.102  -1.1  -0.7  -1.8   0.0
# 4  16.5  ...   16.0  16.2  3.3  3.1  6.5  0.130  -0.7   1.2   0.6   1.5
#
# [5 rows x 29 columns]

# %%
fa_salary2017 = pd.read_csv('salary-data/fa-signings/2017.csv')
#adv_stats = adv_stats.drop(['Unnamed: 19','Unnamed: 24'], axis = 1)
fa_salary2017.head()
# Out:
#    last name first name  age position team faStatus  total-contract   average
# 0      Curry    Stephen   29       PG  GSW      UFA       201158790  40231758
# 1    Griffin      Blake   28       PF  LAC      UFA       171174820  34234964
# 2    Holiday       Jrue   27       PG  NOP      UFA       131805000  26361000
# 3    Hayward     Gordon   27       SF  UTH      UFA       127829970  31957493
# 4  PorterJr.       Otto   24       SF  WAS      RFA       106524975  26631244

# %%
name_temp = (fa_salary2017['first name'] + fa_salary2017['last name']).str.lower()
fa_salary2017.insert(0, 'name', name_temp.map(lambda x: re.sub("[^a-zA-Z]+", "", x)))
fa_salary2017.head()
# Out:
#             name  last name first name  age position team faStatus  \
# 0   stephencurry      Curry    Stephen   29       PG  GSW      UFA
# 1   blakegriffin    Griffin      Blake   28       PF  LAC      UFA
# 2    jrueholiday    Holiday       Jrue   27       PG  NOP      UFA
# 3  gordonhayward    Hayward     Gordon   27       SF  UTH      UFA
# 4   ottoporterjr  PorterJr.       Otto   24       SF  WAS      RFA
#
#    total-contract   average
# 0       201158790  40231758
# 1       171174820  34234964
# 2       131805000  26361000
# 3       127829970  31957493
# 4       106524975  26631244

# %%
posBigOrSmall(fa_salary2017, "position", 5)
fa_salary2017.head()
# Out:
#             name  last name first name  age position    pos team faStatus  \
# 0   stephencurry      Curry    Stephen   29       PG  small  GSW      UFA
# 1   blakegriffin    Griffin      Blake   28       PF    big  LAC      UFA
# 2    jrueholiday    Holiday       Jrue   27       PG  small  NOP      UFA
# 3  gordonhayward    Hayward     Gordon   27       SF    big  UTH      UFA
# 4   ottoporterjr  PorterJr.       Otto   24       SF    big  WAS      RFA
#
#    total-contract   average
# 0       201158790  40231758
# 1       171174820  34234964
# 2       131805000  26361000
# 3       127829970  31957493
# 4       106524975  26631244

# %%
fa2017_combined = adv_stats2017.merge(fa_salary2017, how = 'inner', on = ['name', 'pos', 'team'])
fa2017_combined.head()
# Out:
#    Rk          name                   Player Pos    pos  Age team   G    MP  \
# 0   4  arronafflalo  Arron Afflalo\afflaar01  SG  small   31  SAC  61  1580
# 1   9     tonyallen     Tony Allen\allento01  SG  small   35  MEM  71  1914
# 2  23   lukebabbitt   Luke Babbitt\babbilu01  SF    big   27  MIA  68  1065
# 3  24      ronbaker      Ron Baker\bakerro01  SG  small   23  NYK  52   857
# 4  34    aronbaynes    Aron Baynes\baynear01   C    big   30  DET  75  1163
#
#     PER   ...     DBPM  BPM  VORP  last name  first name  age  position  \
# 0   8.9   ...     -2.1 -3.5  -0.6    Afflalo       Arron   31        SG
# 1  13.3   ...      2.4  0.6   1.3      Allen        Tony   35        SG
# 2   8.3   ...     -0.9 -1.9   0.0    Babbitt        Luke   28        SF
# 3   7.5   ...     -0.9 -4.4  -0.5      Baker         Ron   24        SG
# 4  13.1   ...      1.1 -1.8   0.1     Baynes        Aron   30        PF
#
#    faStatus  total-contract  average
# 0       UFA         2328652  2328652
# 1       UFA         2328652  2328652
# 2       UFA         1974159  1974159
# 3       UFA         8872400  4436200
# 4       UFA         4328000  4328000
#
# [5 rows x 36 columns]

# %%
'''
for year in ['2011', '2012', '2013', '2014', '2015', '2016', '2017']:
    salary_table = pd.read_csv('salary-data/fa-signings/' + year + '.csv')
    names = salary_table['first name'] + salary_table['last name']
    for i in range(len(names)):
        if re.search("[^a-zA-Z.\\\\]", names[i]) != None:
            print("salary " + year + " " + names[i])
    
    stats_table = pd.read_csv('player-data/player' + year + '/Adv-' + year + '.csv')
    names = stats_table['Player'].map(lambda x: re.search("^.*(?=\\\\)", x).group(0).replace(" ", ""))
    for i in range(len(names)):
        if re.search("[^a-zA-Z.\\\\]", names[i]) != None:
            print("stats " + year + " " + names[i])
'''
# Out:
# '\nfor year in [\'2011\', \'2012\', \'2013\', \'2014\', \'2015\', \'2016\', \'2017\']:\n    salary_table = pd.read_csv(\'salary-data/fa-signings/\' + year + \'.csv\')\n    names = salary_table[\'first name\'] + salary_table[\'last name\']\n    for i in range(len(names)):\n        if re.search("[^a-zA-Z.\\\\]", names[i]) != None:\n            print("salary " + year + " " + names[i])\n    \n    stats_table = pd.read_csv(\'player-data/player\' + year + \'/Adv-\' + year + \'.csv\')\n    names = stats_table[\'Player\'].map(lambda x: re.search("^.*(?=\\\\)", x).group(0).replace(" ", ""))\n    for i in range(len(names)):\n        if re.search("[^a-zA-Z.\\\\]", names[i]) != None:\n            print("stats " + year + " " + names[i])\n'

# %%
combined_names = fa2017_combined['name'].tolist()
fa_names = fa_salary2017['name'].tolist()
differing_names = []
for i in range((len(fa_names))):
    if fa_names[i] not in combined_names:
        differing_names.append(fa_names[i])
differing_names
# Out:
# ['gordonhayward',
#  'ottoporterjr',
#  'timhardawayjr',
#  'georgehill',
#  'joeingles',
#  'patrickmills',
#  'andreiguodala',
#  'tonysnell',
#  'andreroberson',
#  'cjmiles',
#  'alanwilliams',
#  'shelvinmack',
#  'jamalcrawford',
#  'vincecarter',
#  'nickyoung',
#  'jeffwithey',
#  'diamondstone',
#  'geraldgreen',
#  'ramonsessions',
#  'lucrichard',
#  'mikescott',
#  'kjmcdaniels',
#  'brianteweber',
#  'jarroduthoff']

# %%
adv_stats2017[adv_stats2017['name'].map(lambda x: x in differing_names)]
# Out:
#       Rk           name                    Player Pos    pos  Age team   G  \
# 88    73    vincecarter    Vince Carter\cartevi01  SF    big   40  MEM  73
# 115   93  jamalcrawford  Jamal Crawford\crawfja01  SG  small   36  LAC  82
# 203  165    geraldgreen    Gerald Green\greenge01  SF    big   31  BOS  47
# 225  185  gordonhayward  Gordon Hayward\haywago01  SF    big   26  UTA  73
# 238  194     georgehill      George Hill\hillge01  PG  small   30  UTA  49
# 257  211  andreiguodala  Andre Iguodala\iguodan01  SF    big   33  GSW  76
# 262  213      joeingles      Joe Ingles\inglejo01  SF    big   29  UTA  82
# 338  279    shelvinmack     Shelvin Mack\macksh01  PG  small   26  UTA  55
# 352  291    kjmcdaniels  K.J. McDaniels\mcdankj01  SF    big   23  TOT  49
# 353  291    kjmcdaniels  K.J. McDaniels\mcdankj01  SF    big   23  HOU  29
# 354  291    kjmcdaniels  K.J. McDaniels\mcdankj01  SF    big   23  BRK  20
# 367  302        cjmiles      C.J. Miles\milescj01  SF    big   29  IND  76
# 460  377  andreroberson  Andre Roberson\roberan03  SF    big   25  OKC  79
# 481  396      mikescott      Mike Scott\scottmi01  PF    big   28  ATL  18
# 487  400  ramonsessions  Ramon Sessions\sessira01  PG  small   30  CHO  50
# 496  409      tonysnell      Tony Snell\snellto01  SG  small   25  MIL  80
# 505  415   diamondstone   Diamond Stone\stonedi01   C    big   19  LAC   7
# 537  439   jarroduthoff   Jarrod Uthoff\uthofja01  PF    big   23  DAL   9
# 554  456   brianteweber   Briante Weber\weberbr01  PG  small   24  TOT  20
# 555  456   brianteweber   Briante Weber\weberbr01  PG  small   24  GSW   7
# 556  456   brianteweber   Briante Weber\weberbr01  PG  small   24  CHO  13
# 564  464   alanwilliams   Alan Williams\willial03   C    big   24  PHO  47
# 581  473     jeffwithey     Jeff Withey\witheje01   C    big   26  UTA  51
# 588  480      nickyoung      Nick Young\youngni01  SG  small   31  LAL  60
#
#        MP   PER  ...   TOV%  USG%  OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  \
# 88   1799  11.7  ...    8.5  14.9  1.9  2.1   4.0  0.106   0.1   0.9   1.0
# 115  2157  12.0  ...   12.3  22.7  0.5  1.4   1.9  0.043  -1.0  -2.1  -3.0
# 203   538  11.9  ...    9.1  22.7  0.1  0.4   0.6  0.050  -2.0  -2.8  -4.7
# 225  2516  22.2  ...    9.4  27.6  7.1  3.3  10.4  0.199   4.2   0.0   4.2
# 238  1544  19.3  ...   10.9  23.5  4.0  1.9   5.9  0.182   3.9  -0.2   3.6
# 257  1998  14.3  ...   11.2  11.2  4.1  2.9   6.9  0.167   1.3   1.7   3.0
# 262  1972  12.4  ...   18.2  13.9  2.0  3.0   5.0  0.123   0.9   1.8   2.7
# 338  1205  10.9  ...   17.8  19.6 -0.1  1.5   1.4  0.054  -1.7  -0.1  -1.8
# 352   505  11.5  ...   13.5  18.1  0.0  0.5   0.5  0.051  -3.5  -0.6  -4.1
# 353   212  10.2  ...   12.1  16.4  0.0  0.2   0.3  0.058  -3.7  -1.0  -4.7
# 354   293  12.5  ...   14.4  19.3  0.0  0.3   0.3  0.046  -3.2  -0.4  -3.7
# 367  1776  13.8  ...    5.5  18.4  2.7  1.4   4.0  0.109   1.6  -2.1  -0.5
# 460  2376   9.6  ...    9.1  10.1  1.1  3.1   4.2  0.085  -2.1   2.1   0.0
# 481   195   5.9  ...   11.3  15.8 -0.3  0.2  -0.1 -0.014  -5.3  -0.1  -5.3
# 487   811  12.4  ...   12.7  20.1  0.3  0.6   0.9  0.055  -2.4  -2.2  -4.6
# 496  2336   9.7  ...    8.8  12.1  2.1  1.3   3.4  0.071   0.2  -1.1  -0.8
# 505    24  -1.2  ...   11.9  31.3 -0.1  0.0  -0.1 -0.211 -17.3  -6.8 -24.1
# 537   115  13.9  ...    6.8  18.1  0.1  0.1   0.2  0.083  -2.1   0.7  -1.4
# 554   205  11.0  ...   10.7  16.3  0.0  0.2   0.3  0.059  -3.2   0.0  -3.2
# 555    46   5.9  ...   16.4  17.2 -0.1  0.1   0.0 -0.018  -6.9   0.7  -6.2
# 556   159  12.5  ...    8.8  16.1  0.1  0.2   0.3  0.081  -2.1  -0.2  -2.3
# 564   708  19.5  ...   10.5  20.9  1.1  0.9   2.1  0.142  -1.8   0.1  -1.7
# 581   432  18.8  ...   10.1  14.9  1.0  0.9   1.8  0.205  -1.2   2.7   1.6
# 588  1556  14.1  ...    5.1  19.5  3.0  0.2   3.2  0.098   2.7  -3.4  -0.7
#
#      VORP
# 88    1.4
# 115  -0.6
# 203  -0.4
# 225   4.0
# 238   2.2
# 257   2.5
# 262   2.3
# 338   0.1
# 352  -0.3
# 353  -0.1
# 354  -0.1
# 367   0.7
# 460   1.2
# 481  -0.2
# 487  -0.5
# 496   0.7
# 505  -0.1
# 537   0.0
# 554  -0.1
# 555   0.0
# 556   0.0
# 564   0.1
# 581   0.4
# 588   0.5
#
# [24 rows x 29 columns]

# %%
fa_salary2017[fa_salary2017['name'].map(lambda x: x in differing_names)]
# Out:
#               name    last name first name  age position    pos team faStatus  \
# 3    gordonhayward      Hayward     Gordon   27       SF    big  UTH      UFA
# 4     ottoporterjr    PorterJr.       Otto   24       SF    big  WAS      RFA
# 6    timhardawayjr  HardawayJr.        Tim   25       SG  small  ATL      RFA
# 10      georgehill         Hill     George   31       PG  small  UTH      UFA
# 12       joeingles       Ingles        Joe   29       SF    big  UTH      RFA
# 16    patrickmills        Mills    Patrick   29       PG  small  SAS      UFA
# 18   andreiguodala     Iguodala      Andre   33       SG  small  GSW      UFA
# 19       tonysnell        Snell       Tony   25       SF    big  MIL      RFA
# 24   andreroberson     Roberson      Andre   25       SG  small  OKC      RFA
# 27         cjmiles        Miles       C.J.   30       SG  small  IND      UFA
# 39    alanwilliams     Williams       Alan   24       PF    big  PHX      RFA
# 42     shelvinmack         Mack    Shelvin   27       PG  small  UTH      UFA
# 50   jamalcrawford     Crawford      Jamal   37       SG  small  ATL      UFA
# 52     vincecarter       Carter      Vince   40       SG  small  MEM      UFA
# 55       nickyoung        Young       Nick   32       SF    big  LAL      UFA
# 64      jeffwithey       Withey       Jeff   27        C    big  UTH      UFA
# 71    diamondstone        Stone    Diamond   20        C    big  ATL      UFA
# 75     geraldgreen        Green     Gerald   31       SG  small  BOS      UFA
# 78   ramonsessions     Sessions      Ramon   31       PG  small  CHA      UFA
# 92      lucrichard      Richard        Luc   31       SF    big  LAC      UFA
# 96       mikescott        Scott       Mike   29       PF    big  PHX      UFA
# 100    kjmcdaniels    McDaniels       K.J.   24       SG  small  BKN      UFA
# 102   brianteweber        Weber    Briante   24       SG  small  CHA      UFA
# 104   jarroduthoff       Uthoff     Jarrod   24       PF    big  HOU      UFA
#
#      total-contract   average
# 3         127829970  31957493
# 4         106524975  26631244
# 6          70950000  17737500
# 10         57000000  19000000
# 12         52000000  13000000
# 16         49714285  12428571
# 18         48000000  16000000
# 19         46000000  11500000
# 24         30000000  10000000
# 27         25000000   8333333
# 39         17000000   5666667
# 42         12000000   6000000
# 50          8872400   4436200
# 52          8000000   8000000
# 55          5192000   5192000
# 64          3372245   1686123
# 71          2857562   1428781
# 75          2328652   2328652
# 78          2328652   2328652
# 92          2116955   2116955
# 96          1709538   1709538
# 100         1524305   1524305
# 102         1471382   1471382
# 104         1312611   1312611
