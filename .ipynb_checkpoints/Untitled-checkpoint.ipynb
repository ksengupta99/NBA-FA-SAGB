# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import Perceptron
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.utils import shuffle

from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
adv_stats2017 = pd.read_csv('player-data/player2017/Adv-2017.csv')
adv_stats2017 = adv_stats2017.drop(['Unnamed: 19','Unnamed: 24'], axis = 1)
adv_stats2017.rename(columns = {'Tm': 'team'}, inplace = True)
adv_stats2017.head()
# Out:
#    Rk                  Player Pos  Age team   G    MP   PER    TS%   3PAr  \
# 0   1  Alex Abrines\abrinal01  SG   23  OKC  68  1055  10.1  0.560  0.724
# 1   2      Quincy Acy\acyqu01  PF   26  TOT  38   558  11.8  0.565  0.529
# 2   2      Quincy Acy\acyqu01  PF   26  DAL   6    48  -1.4  0.355  0.412
# 3   2      Quincy Acy\acyqu01  PF   26  BRK  32   510  13.1  0.587  0.542
# 4   3  Steven Adams\adamsst01   C   23  OKC  80  2389  16.5  0.589  0.002
#
#    ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP
# 0  ...    8.3  15.9  1.2  0.9  2.1  0.096  -0.3  -2.2  -2.5  -0.1
# 1  ...    9.7  16.8  0.5  0.5  0.9  0.082  -1.8  -1.2  -3.0  -0.1
# 2  ...    9.8  20.0 -0.2  0.0 -0.1 -0.133 -10.1  -6.0 -16.2  -0.2
# 3  ...    9.6  16.5  0.6  0.5  1.1  0.102  -1.1  -0.7  -1.8   0.0
# 4  ...   16.0  16.2  3.3  3.1  6.5  0.130  -0.7   1.2   0.6   1.5
#
# [5 rows x 27 columns]

# %%
name_temp = adv_stats2017['Player'].map(lambda x: 
                                        re.sub("[^a-zA-Z]+", "", 
                                               re.search("^.*(?=\\\\)", x).group(0).replace(" ", "").lower()))
adv_stats2017.insert(1, 'name', name_temp.map(lambda x: re.sub("[^a-zA-Z]+", "", x)))
adv_stats2017.head()
# Out:
#    Rk         name                  Player Pos  Age team   G    MP   PER  \
# 0   1  alexabrines  Alex Abrines\abrinal01  SG   23  OKC  68  1055  10.1
# 1   2    quincyacy      Quincy Acy\acyqu01  PF   26  TOT  38   558  11.8
# 2   2    quincyacy      Quincy Acy\acyqu01  PF   26  DAL   6    48  -1.4
# 3   2    quincyacy      Quincy Acy\acyqu01  PF   26  BRK  32   510  13.1
# 4   3  stevenadams  Steven Adams\adamsst01   C   23  OKC  80  2389  16.5
#
#      TS%  ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP
# 0  0.560  ...    8.3  15.9  1.2  0.9  2.1  0.096  -0.3  -2.2  -2.5  -0.1
# 1  0.565  ...    9.7  16.8  0.5  0.5  0.9  0.082  -1.8  -1.2  -3.0  -0.1
# 2  0.355  ...    9.8  20.0 -0.2  0.0 -0.1 -0.133 -10.1  -6.0 -16.2  -0.2
# 3  0.587  ...    9.6  16.5  0.6  0.5  1.1  0.102  -1.1  -0.7  -1.8   0.0
# 4  0.589  ...   16.0  16.2  3.3  3.1  6.5  0.130  -0.7   1.2   0.6   1.5
#
# [5 rows x 28 columns]

# %%
#Takes in a dataframe, a position column name ("Pos" for stats df, "position" for salary df), 
#and index to insert new column into (4 for stats df, 5 for salary df).
#So call to a stats df should be posBigOrSmall(stats_df, "Pos", 4) 
#and for salary df posBigOrSmall(salary_df, "position", 5)
def posBigOrSmall(df, pos_colname, col_index):
    pos = []
    for i in range(len(df)):
        if df[pos_colname][i] == "PG" or df[pos_colname][i] == "SG":
            pos.append("small")
        else:
            pos.append("big")
    df.insert(col_index, 'pos', pos)

# %%
posBigOrSmall(adv_stats2017, "Pos", 4) 
adv_stats2017.head()
# Out:
#    Rk         name                  Player Pos    pos  Age team   G    MP  \
# 0   1  alexabrines  Alex Abrines\abrinal01  SG  small   23  OKC  68  1055
# 1   2    quincyacy      Quincy Acy\acyqu01  PF    big   26  TOT  38   558
# 2   2    quincyacy      Quincy Acy\acyqu01  PF    big   26  DAL   6    48
# 3   2    quincyacy      Quincy Acy\acyqu01  PF    big   26  BRK  32   510
# 4   3  stevenadams  Steven Adams\adamsst01   C    big   23  OKC  80  2389
#
#     PER  ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP
# 0  10.1  ...    8.3  15.9  1.2  0.9  2.1  0.096  -0.3  -2.2  -2.5  -0.1
# 1  11.8  ...    9.7  16.8  0.5  0.5  0.9  0.082  -1.8  -1.2  -3.0  -0.1
# 2  -1.4  ...    9.8  20.0 -0.2  0.0 -0.1 -0.133 -10.1  -6.0 -16.2  -0.2
# 3  13.1  ...    9.6  16.5  0.6  0.5  1.1  0.102  -1.1  -0.7  -1.8   0.0
# 4  16.5  ...   16.0  16.2  3.3  3.1  6.5  0.130  -0.7   1.2   0.6   1.5
#
# [5 rows x 29 columns]

# %%
fa_salary2017 = pd.read_csv('salary-data/fa-signings/2017.csv')
#adv_stats = adv_stats.drop(['Unnamed: 19','Unnamed: 24'], axis = 1)
fa_salary2017.head()
# Out:
#    last name first name  age position team faStatus  total-contract   average
# 0      Curry    Stephen   29       PG  GSW      UFA       201158790  40231758
# 1    Griffin      Blake   28       PF  LAC      UFA       171174820  34234964
# 2    Holiday       Jrue   27       PG  NOP      UFA       131805000  26361000
# 3    Hayward     Gordon   27       SF  UTH      UFA       127829970  31957493
# 4  PorterJr.       Otto   24       SF  WAS      RFA       106524975  26631244

# %%
name_temp = (fa_salary2017['first name'] + fa_salary2017['last name']).str.lower()
fa_salary2017.insert(0, 'name', name_temp.map(lambda x: re.sub("[^a-zA-Z]+", "", x)))
fa_salary2017.head()
# Out:
#             name  last name first name  age position team faStatus  \
# 0   stephencurry      Curry    Stephen   29       PG  GSW      UFA
# 1   blakegriffin    Griffin      Blake   28       PF  LAC      UFA
# 2    jrueholiday    Holiday       Jrue   27       PG  NOP      UFA
# 3  gordonhayward    Hayward     Gordon   27       SF  UTH      UFA
# 4   ottoporterjr  PorterJr.       Otto   24       SF  WAS      RFA
#
#    total-contract   average
# 0       201158790  40231758
# 1       171174820  34234964
# 2       131805000  26361000
# 3       127829970  31957493
# 4       106524975  26631244

# %%
posBigOrSmall(fa_salary2017, "position", 5)
fa_salary2017.head()
# Out:
#             name  last name first name  age position    pos team faStatus  \
# 0   stephencurry      Curry    Stephen   29       PG  small  GSW      UFA
# 1   blakegriffin    Griffin      Blake   28       PF    big  LAC      UFA
# 2    jrueholiday    Holiday       Jrue   27       PG  small  NOP      UFA
# 3  gordonhayward    Hayward     Gordon   27       SF    big  UTH      UFA
# 4   ottoporterjr  PorterJr.       Otto   24       SF    big  WAS      RFA
#
#    total-contract   average
# 0       201158790  40231758
# 1       171174820  34234964
# 2       131805000  26361000
# 3       127829970  31957493
# 4       106524975  26631244

# %%
adv_stats2017.merge(fa_salary2017, how = 'inner', on = ['name', 'pos', 'team'])
# Out:
#      Rk                    name                              Player Pos  \
# 0     4            arronafflalo             Arron Afflalo\afflaar01  SG
# 1     9               tonyallen                Tony Allen\allento01  SG
# 2    23             lukebabbitt              Luke Babbitt\babbilu01  SF
# 3    24                ronbaker                 Ron Baker\bakerro01  SG
# 4    34              aronbaynes               Aron Baynes\baynear01   C
# 5    38          michaelbeasley           Michael Beasley\beaslmi01  PF
# 6    48              tarikblack               Tarik Black\blackta01   C
# 7    50         bojanbogdanovic          Bojan Bogdanovic\bogdabo02  SF
# 8    58             aaronbrooks              Aaron Brooks\brookaa01  PG
# 9    60              bobbybrown               Bobby Brown\brownbo02  PG
# 10   63           reggiebullock            Reggie Bullock\bullore01  SF
# 11   68            josecalderon             Jose Calderon\caldejo01  PG
# 12   69  kentaviouscaldwellpope  Kentavious Caldwell-Pope\caldwke01  SG
# 13   74   michaelcarterwilliams   Michael Carter-Williams\cartemi01  PG
# 14   75              omricasspi               Omri Casspi\casspom01  SF
# 15   82                ianclark                 Ian Clark\clarkia01  SG
# 16   85          darrencollison           Darren Collison\collida01  PG
# 17   86            nickcollison             Nick Collison\collini01  PF
# 18   89               quinncook                 Quinn Cook\cookqu01  PG
# 19   96         dantecunningham          Dante Cunningham\cunnida01  SF
# 20   98            stephencurry             Stephen Curry\curryst01  PG
# 21  103           dewaynededmon            Dewayne Dedmon\dedmode01   C
# 22  119             kevindurant              Kevin Durant\duranke01  SF
# 23  126              tylerennis               Tyler Ennis\ennisty01  PG
# 24  127             tyrekeevans              Tyreke Evans\evansty01  SF
# 25  133        cristianofelicio         Cristiano Felicio\feliccr01   C
# 26  134           raymondfelton            Raymond Felton\feltora01  PG
# 27  142         danilogallinari          Danilo Gallinari\gallida01  SF
# 28  143        langstongalloway         Langston Galloway\gallola01  PG
# 29  146                paugasol                 Pau Gasol\gasolpa01   C
# ..  ...                     ...                                 ...  ..
# 56  312           anthonymorrow            Anthony Morrow\morroan01  SG
# 57  316         shabazzmuhammad          Shabazz Muhammad\muhamsh01  SF
# 58  319             mikemuscala              Mike Muscala\muscami01   C
# 59  326            georgesniang             Georges Niang\niangge01  PF
# 60  329             nerlensnoel               Nerlens Noel\noelne01   C
# 61  332            dirknowitzki             Dirk Nowitzki\nowitdi01  PF
# 62  340             kellyolynyk              Kelly Olynyk\olynyke01   C
# 63  344            zazapachulia             Zaza Pachulia\pachuza01   C
# 64  350        patrickpatterson         Patrick Patterson\pattepa01  PF
# 65  357         marshallplumlee          Marshall Plumlee\plumlma02   C
# 66  358            masonplumlee             Mason Plumlee\plumlma01   C
# 67  371            zachrandolph             Zach Randolph\randoza01  PF
# 68  372                jjredick               J.J. Redick\redicjj01  SG
# 69  373              williereed                Willie Reed\reedwi02   C
# 70  382              rajonrondo               Rajon Rondo\rondora01  PG
# 71  383             derrickrose               Derrick Rose\rosede01  PG
# 72  387             damjanrudez              Damjan Rudez\rudezda01  SF
# 73  397          thabosefolosha           Thabo Sefolosha\sefolth01  SF
# 74  398             wayneselden              Wayne Selden\seldewa01  SG
# 75  403         jonathonsimmons          Jonathon Simmons\simmojo02  SG
# 76  410        marreesespeights         Marreese Speights\speigma01   C
# 77  420              jeffteague               Jeff Teague\teaguje01  PG
# 78  423              jasonterry               Jason Terry\terryja01  SG
# 79  431         anthonytolliver          Anthony Tolliver\tollian01  PF
# 80  434                pjtucker               P.J. Tucker\tuckepj01  SF
# 81  450             dionwaiters              Dion Waiters\waitedi01  SG
# 82  457               davidwest                 David West\westda01   C
# 83  470            troywilliams             Troy Williams\willitr02  SF
# 84  483             tylerzeller              Tyler Zeller\zellety01   C
# 85  484        stephenzimmerman         Stephen Zimmerman\zimmest01   C
#
#       pos  Age team   G    MP   PER    ...     DBPM   BPM  VORP  \
# 0   small   31  SAC  61  1580   8.9    ...     -2.1  -3.5  -0.6
# 1   small   35  MEM  71  1914  13.3    ...      2.4   0.6   1.3
# 2     big   27  MIA  68  1065   8.3    ...     -0.9  -1.9   0.0
# 3   small   23  NYK  52   857   7.5    ...     -0.9  -4.4  -0.5
# 4     big   30  DET  75  1163  13.1    ...      1.1  -1.8   0.1
# 5     big   28  MIL  56   935  17.8    ...     -1.1  -2.9  -0.2
# 6     big   25  LAL  67  1091  15.0    ...      0.2  -1.6   0.1
# 7     big   27  WAS  26   601  14.7    ...     -3.1  -2.6  -0.1
# 8   small   32  IND  65   894   9.5    ...     -2.5  -4.6  -0.6
# 9   small   32  HOU  25   123  10.8    ...     -6.1  -7.6  -0.2
# 10    big   25  DET  31   467  11.7    ...      0.5   0.1   0.2
# 11  small   35  ATL  17   247   8.7    ...     -1.4  -4.2  -0.1
# 12  small   23  DET  76  2529  12.8    ...      0.0   0.9   1.8
# 13  small   25  CHI  45   846   9.9    ...      1.7  -2.4  -0.1
# 14    big   28  MIN  13   222   7.5    ...      0.7  -1.6   0.0
# 15  small   25  GSW  77  1137  13.1    ...     -1.4  -2.0   0.0
# 16  small   29  SAC  68  2063  15.3    ...     -2.3  -1.5   0.3
# 17    big   36  OKC  20   128  12.9    ...      0.0  -1.8   0.0
# 18  small   23  NOP   9   111  15.3    ...     -4.0  -4.0  -0.1
# 19    big   29  NOP  66  1649  10.2    ...      0.8  -0.5   0.6
# 20  small   28  GSW  79  2638  24.6    ...     -0.4   7.3   6.2
# 21    big   27  SAS  76  1330  16.0    ...      3.2   1.7   1.2
# 22    big   28  GSW  62  2070  27.6    ...      2.6   8.0   5.2
# 23  small   22  LAL  22   392  14.3    ...     -2.8  -2.7  -0.1
# 24    big   27  SAC  14   314  14.9    ...     -1.2  -2.2   0.0
# 25    big   24  CHI  66  1040  15.3    ...      0.6   0.0   0.5
# 26  small   32  LAC  80  1700  10.9    ...      0.8  -1.0   0.4
# 27    big   28  DEN  63  2134  17.4    ...     -2.1   0.8   1.5
# 28  small   25  SAC  19   375   8.0    ...     -2.4  -5.0  -0.3
# 29    big   36  SAS  64  1627  20.2    ...      2.8   3.7   2.4
# ..    ...  ...  ...  ..   ...   ...    ...      ...   ...   ...
# 56  small   31  CHI   9    87  16.0    ...     -4.4  -2.4   0.0
# 57    big   24  MIN  78  1516  14.9    ...     -4.3  -4.4  -0.9
# 58    big   25  ATL  70  1237  14.4    ...      1.5   1.1   1.0
# 59    big   23  IND  23    93   0.1    ...     -2.2 -12.0  -0.2
# 60    big   22  DAL  22   483  19.8    ...      3.8   2.5   0.5
# 61    big   38  DAL  54  1424  17.0    ...      0.3  -1.3   0.2
# 62    big   25  BOS  75  1538  15.3    ...      0.5   0.7   1.0
# 63    big   32  GSW  70  1268  16.1    ...      3.0   2.7   1.5
# 64    big   27  TOR  65  1599  10.8    ...      0.4   0.9   1.2
# 65    big   24  NYK  21   170  10.9    ...      0.1  -2.8   0.0
# 66    big   26  DEN  27   632  16.3    ...      2.2   1.5   0.6
# 67    big   35  MEM  73  1786  18.5    ...     -0.7  -2.1   0.0
# 68  small   32  LAC  78  2198  14.8    ...     -2.1  -0.1   1.1
# 69    big   26  MIA  71  1031  17.1    ...      0.7  -0.6   0.4
# 70  small   30  CHI  69  1843  13.6    ...      1.6   0.3   1.1
# 71  small   28  NYK  64  2082  17.0    ...     -2.2  -1.9   0.0
# 72    big   30  ORL  45   314   6.3    ...     -1.9  -4.6  -0.2
# 73    big   32  ATL  62  1596  11.9    ...      3.1   1.2   1.3
# 74  small   22  MEM  11   189   6.2    ...     -1.9  -6.0  -0.2
# 75  small   27  SAS  78  1392   9.9    ...      0.9  -1.9   0.0
# 76    big   29  LAC  82  1286  17.5    ...     -0.8   0.7   0.9
# 77  small   28  IND  82  2657  19.2    ...     -0.5   1.9   2.6
# 78  small   39  MIL  74  1365   9.1    ...     -0.6  -1.1   0.3
# 79    big   31  SAC  65  1477  11.1    ...     -0.7  -0.4   0.6
# 80    big   31  TOR  24   609  10.4    ...      1.9   1.1   0.5
# 81  small   25  MIA  46  1384  14.5    ...     -0.8  -0.9   0.4
# 82    big   36  GSW  68   854  16.6    ...      3.9   2.2   0.9
# 83    big   22  HOU   6   139  12.8    ...     -2.1  -1.7   0.0
# 84    big   27  BOS  51   525  13.0    ...      0.8  -2.5  -0.1
# 85    big   20  ORL  19   108   7.3    ...      0.4  -7.3  -0.1
#
#           last name  first name  age  position  faStatus  total-contract  \
# 0           Afflalo       Arron   31        SG       UFA         2328652
# 1             Allen        Tony   35        SG       UFA         2328652
# 2           Babbitt        Luke   28        SF       UFA         1974159
# 3             Baker         Ron   24        SG       UFA         8872400
# 4            Baynes        Aron   30        PF       UFA         4328000
# 5           Beasley     Michael   28        SF       UFA         2116955
# 6             Black       Tarik   25         C       UFA         3290000
# 7        Bogdanovic       Bojan   28        SF       UFA        21000000
# 8            Brooks       Aaron   32        PG       UFA         2116955
# 9             Brown       Bobby   33        PG       RFA         1312611
# 10          Bullock      Reggie   26        SF       RFA         5000000
# 11         Calderon        Jose   35        PG       UFA         2328652
# 12    Caldwell-Pope  Kentavious   24        SG       UFA        17745894
# 13  Carter-Williams     Michael   25        PG       UFA         2700000
# 14           Casspi        Omri   29        SF       UFA         2106470
# 15            Clark         Ian   26        SG       UFA         1577230
# 16         Collison      Darren   30        PG       UFA        20000000
# 17         Collison        Nick   36        PF       UFA         2328652
# 18             Cook       Quinn   24        PG       UFA         2857562
# 19       Cunningham       Dante   30        PF       UFA         2300000
# 20            Curry     Stephen   29        PG       UFA       201158790
# 21           Dedmon     Dewayne   28         C       UFA        14100000
# 22           Durant       Kevin   28        SF       UFA        51250000
# 23            Ennis       Tyler   23        PG       UFA         3180397
# 24            Evans      Tyreke   28        SF       UFA         3290000
# 25          Felicio   Cristiano   25        PF       RFA        32000000
# 26           Felton     Raymond   33        PG       UFA         2328652
# 27        Gallinari      Danilo   29        SF       UFA        64762737
# 28         Galloway    Langston   25        PG       RFA        21000000
# 29            Gasol         Pau   37        PF       UFA        48800000
# ..              ...         ...  ...       ...       ...             ...
# 56           Morrow     Anthony   31        SG       UFA         2116955
# 57         Muhammad     Shabazz   24        SF       UFA         3372245
# 58          Muscala        Mike   26        PF       UFA        10000000
# 59            Niang     Georges   24        SF       UFA         1312611
# 60             Noel     Nerlens   23         C       RFA         4187598
# 61         Nowitzki        Dirk   39        PF       UFA         5000000
# 62           Olynyk       Kelly   26         C       UFA        50000000
# 63         Pachulia        Zaza   33         C       UFA         3477600
# 64        Patterson     Patrick   28        PF       UFA        16354800
# 65          Plumlee    Marshall   25        PF       UFA         1312611
# 66          Plumlee       Mason   27         C       RFA        41000000
# 67         Randolph        Zach   36        PF       UFA        24000000
# 68           Redick        J.J.   33        SG       UFA        23000000
# 69             Reed      Willie   27        PF       UFA         1577230
# 70            Rondo       Rajon   31        PG       UFA         3300000
# 71             Rose     Derrick   28        PG       UFA         2106470
# 72            Rudez      Damjan   31        SF       RFA         1524305
# 73        Sefolosha       Thabo   33        SF       UFA        10500000
# 74           Selden       Wayne   22        SG       UFA         2857562
# 75          Simmons    Jonathon   28        SG       UFA        20000000
# 76         Speights    Marreese   30         C       UFA         2116955
# 77           Teague        Jeff   29        PG       UFA        57000000
# 78            Terry       Jason   40        SG       UFA         2328652
# 79         Tolliver     Anthony   32        PF       UFA         3290000
# 80           Tucker        P.J.   32        SF       UFA        31878148
# 81          Waiters        Dion   25        SG       UFA        52000000
# 82             West       David   37        PF       UFA         2328652
# 83         Williams        Troy   22        SF       RFA         4693068
# 84           Zeller       Tyler   27         C       UFA         3643479
# 85        Zimmerman     Stephen   21         C       UFA         1312611
#
#      average
# 0    2328652
# 1    2328652
# 2    1974159
# 3    4436200
# 4    4328000
# 5    2116955
# 6    3290000
# 7   10500000
# 8    2116955
# 9    1312611
# 10   2500000
# 11   2328652
# 12  17745894
# 13   2700000
# 14   2106470
# 15   1577230
# 16  10000000
# 17   2328652
# 18   1428781
# 19   2300000
# 20  40231758
# 21   7050000
# 22  25625000
# 23   1590199
# 24   3290000
# 25   8000000
# 26   2328652
# 27  21587579
# 28   7000000
# 29  16266667
# ..       ...
# 56   2116955
# 57   1686123
# 58   5000000
# 59   1312611
# 60   4187598
# 61   5000000
# 62  12500000
# 63   3477600
# 64   5451600
# 65   1312611
# 66  13666667
# 67  12000000
# 68  23000000
# 69   1577230
# 70   3300000
# 71   2106470
# 72   1524305
# 73   5250000
# 74   1428781
# 75   6666667
# 76   2116955
# 77  19000000
# 78   2328652
# 79   3290000
# 80   7969537
# 81  13000000
# 82   2328652
# 83   1564356
# 84   1821740
# 85   1312611
#
# [86 rows x 36 columns]

# %%
'''
for year in ['2011', '2012', '2013', '2014', '2015', '2016', '2017']:
    salary_table = pd.read_csv('salary-data/fa-signings/' + year + '.csv')
    names = salary_table['first name'] + salary_table['last name']
    for i in range(len(names)):
        if re.search("[^a-zA-Z.\\\\]", names[i]) != None:
            print("salary " + year + " " + names[i])
    
    stats_table = pd.read_csv('player-data/player' + year + '/Adv-' + year + '.csv')
    names = stats_table['Player'].map(lambda x: re.search("^.*(?=\\\\)", x).group(0).replace(" ", ""))
    for i in range(len(names)):
        if re.search("[^a-zA-Z.\\\\]", names[i]) != None:
            print("stats " + year + " " + names[i])
'''
# Out:
# '\nfor year in [\'2011\', \'2012\', \'2013\', \'2014\', \'2015\', \'2016\', \'2017\']:\n    salary_table = pd.read_csv(\'salary-data/fa-signings/\' + year + \'.csv\')\n    names = salary_table[\'first name\'] + salary_table[\'last name\']\n    for i in range(len(names)):\n        if re.search("[^a-zA-Z.\\\\]", names[i]) != None:\n            print("salary " + year + " " + names[i])\n    \n    stats_table = pd.read_csv(\'player-data/player\' + year + \'/Adv-\' + year + \'.csv\')\n    names = stats_table[\'Player\'].map(lambda x: re.search("^.*(?=\\\\)", x).group(0).replace(" ", ""))\n    for i in range(len(names)):\n        if re.search("[^a-zA-Z.\\\\]", names[i]) != None:\n            print("stats " + year + " " + names[i])\n'
